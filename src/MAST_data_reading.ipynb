# %% [markdown]
# ### Data reading

# %%
import numpy as np
import pandas as pd
import re
from pathlib import Path
from astroquery import mast
from astroquery.mast import Catalogs

# %%
WDIR = Path().cwd().parent
EMISSION_DATABASE_PATH = WDIR / "data/emissionspec.csv"
TRANSMISSION_DATABASE_PATH = WDIR / "data/transitspec.csv"


df_emission = pd.read_csv(EMISSION_DATABASE_PATH, header=18, index_col=0)
df_transmission = pd.read_csv(TRANSMISSION_DATABASE_PATH, header=26, index_col=0)

print(df_emission)
print(df_transmission)
# Out:
#          plntname  centralwavelng  bandwidth  especlipdep  especlipdeperr1  \
# rowid
# 1       WASP-80 b           3.600        NaN       0.4550           0.1000
# 2       WASP-80 b           4.500        NaN       0.9440           0.0640
# 3      HAT-P-13 b           3.600        NaN       0.0662           0.0113
# 4      HAT-P-13 b           4.500        NaN       0.1426           0.0130
# 5          XO-3 b           4.500        NaN       0.1580           0.0036
# ...           ...             ...        ...          ...              ...
# 570    WASP-121 b           1.554      0.019       0.1307           0.0062
# 571    WASP-121 b           1.573      0.018       0.1388           0.0063
# 572    WASP-121 b           1.591      0.019       0.1299           0.0069
# 573    WASP-121 b           1.610      0.018       0.1270           0.0064
# 574    WASP-121 b           1.628      0.019       0.1286           0.0068
#
#        especlipdeperr2  especlipdeplim  espbritemp  espbritemperr1  \
# rowid
# 1              -0.1000               0       901.0            68.0
# 2              -0.0650               0       888.0            58.0
# 3              -0.0113               0         NaN             NaN
# 4              -0.0130               0         NaN             NaN
# 5              -0.0036               0         NaN             NaN
# ...                ...             ...         ...             ...
# 570            -0.0060               0         NaN             NaN
# 571            -0.0066               0         NaN             NaN
# 572            -0.0069               0         NaN             NaN
# 573            -0.0063               0         NaN             NaN
# 574            -0.0068               0         NaN             NaN
#
#        espbritemperr2  espbritemplim  \
# rowid
# 1               -72.0            0.0
# 2               -57.0            0.0
# 3                 NaN            NaN
# 4                 NaN            NaN
# 5                 NaN            NaN
# ...               ...            ...
# 570               NaN            NaN
# 571               NaN            NaN
# 572               NaN            NaN
# 573               NaN            NaN
# 574               NaN            NaN
#
#                                              plntreflink  \
# rowid
# 1      <a refstr=TRIAUD_ET_AL__2015 href=https://ui.a...
# 2      <a refstr=TRIAUD_ET_AL__2015 href=https://ui.a...
# 3      <a refstr=BUHLER_ET_AL__2016 href=https://ui.a...
# 4      <a refstr=BUHLER_ET_AL__2016 href=https://ui.a...
# 5      <a refstr=WONG_ET_AL__2014 href=https://ui.ads...
# ...                                                  ...
# 570    <a refstr=MIKAL_EVANS_ET_AL__2020 href=https:/...
# 571    <a refstr=MIKAL_EVANS_ET_AL__2020 href=https:/...
# 572    <a refstr=MIKAL_EVANS_ET_AL__2020 href=https:/...
# 573    <a refstr=MIKAL_EVANS_ET_AL__2020 href=https:/...
# 574    <a refstr=MIKAL_EVANS_ET_AL__2020 href=https:/...
#
#                                 facility                    instrument
# rowid
# 1      Spitzer Space Telescope satellite  Infrared Array Camera (IRAC)
# 2      Spitzer Space Telescope satellite  Infrared Array Camera (IRAC)
# 3      Spitzer Space Telescope satellite  Infrared Array Camera (IRAC)
# 4      Spitzer Space Telescope satellite  Infrared Array Camera (IRAC)
# 5      Spitzer Space Telescope satellite  Infrared Array Camera (IRAC)
# ...                                  ...                           ...
# 570     Hubble Space Telescope satellite           Wide Field Camera 3
# 571     Hubble Space Telescope satellite           Wide Field Camera 3
# 572     Hubble Space Telescope satellite           Wide Field Camera 3
# 573     Hubble Space Telescope satellite           Wide Field Camera 3
# 574     Hubble Space Telescope satellite           Wide Field Camera 3
#
# [574 rows x 14 columns]
#         plntname  centralwavelng  bandwidth  plntransdep  plntransdeperr1  \
# rowid
# 1      WASP-12 b          0.3350      0.090          NaN              NaN
# 2      WASP-12 b          0.4050      0.050          NaN              NaN
# 3      WASP-12 b          0.5020      0.044          NaN              NaN
# 4      WASP-12 b          0.5470      0.046          NaN              NaN
# 5      WASP-12 b          0.5550      0.050          NaN              NaN
# ...          ...             ...        ...          ...              ...
# 5741   WASP-39 b          5.2152        NaN     2.128872         0.019096
# 5742   WASP-39 b          5.2450        NaN     2.151435         0.019834
# 5743   WASP-39 b          5.2746        NaN     2.145262         0.019816
# 5744   WASP-39 b          5.3077        NaN     2.123778         0.018451
# 5745   WASP-39 b          5.3441        NaN     2.116736         0.020963
#
#        plntransdeperr2  plntransdeplim  plnradj  plnradjerr1  plnradjerr2  \
# rowid
# 1                  NaN             NaN      NaN          NaN          NaN
# 2                  NaN             NaN      NaN          NaN          NaN
# 3                  NaN             NaN      NaN          NaN          NaN
# 4                  NaN             NaN      NaN          NaN          NaN
# 5                  NaN             NaN      NaN          NaN          NaN
# ...                ...             ...      ...          ...          ...
# 5741         -0.019096             0.0      NaN          NaN          NaN
# 5742         -0.019834             0.0      NaN          NaN          NaN
# 5743         -0.019816             0.0      NaN          NaN          NaN
# 5744         -0.018451             0.0      NaN          NaN          NaN
# 5745         -0.020963             0.0      NaN          NaN          NaN
#
#        ...  plnratrorerr1  plnratrorerr2  plnratrorlim    plntranmid  \
# rowid  ...
# 1      ...        0.00087       -0.00087           0.0  2.454509e+06
# 2      ...        0.00025       -0.00025           0.0  2.454509e+06
# 3      ...        0.00031       -0.00031           0.0  2.454509e+06
# 4      ...        0.00035       -0.00035           0.0  2.454509e+06
# 5      ...        0.00057       -0.00057           0.0  2.454509e+06
# ...    ...            ...            ...           ...           ...
# 5741   ...            NaN            NaN           NaN           NaN
# 5742   ...            NaN            NaN           NaN           NaN
# 5743   ...            NaN            NaN           NaN           NaN
# 5744   ...            NaN            NaN           NaN           NaN
# 5745   ...            NaN            NaN           NaN           NaN
#
#        plntranmiderr1  plntranmiderr2  plntranmidlim  \
# rowid
# 1             0.00031        -0.00031            0.0
# 2             0.00031        -0.00031            0.0
# 3             0.00031        -0.00031            0.0
# 4             0.00031        -0.00031            0.0
# 5             0.00031        -0.00031            0.0
# ...               ...             ...            ...
# 5741              NaN             NaN            NaN
# 5742              NaN             NaN            NaN
# 5743              NaN             NaN            NaN
# 5744              NaN             NaN            NaN
# 5745              NaN             NaN            NaN
#
#                                           plntranreflink  \
# rowid
# 1      <a refstr=SING_ET_AL__2013 href=https://ui.ads...
# 2      <a refstr=SING_ET_AL__2013 href=https://ui.ads...
# 3      <a refstr=SING_ET_AL__2013 href=https://ui.ads...
# 4      <a refstr=SING_ET_AL__2013 href=https://ui.ads...
# 5      <a refstr=SING_ET_AL__2013 href=https://ui.ads...
# ...                                                  ...
# 5741   <a refstr=RUSTAMKULOV_ET_AL__2022 href=https:/...
# 5742   <a refstr=RUSTAMKULOV_ET_AL__2022 href=https:/...
# 5743   <a refstr=RUSTAMKULOV_ET_AL__2022 href=https:/...
# 5744   <a refstr=RUSTAMKULOV_ET_AL__2022 href=https:/...
# 5745   <a refstr=RUSTAMKULOV_ET_AL__2022 href=https:/...
#
#                                                 facility  \
# rowid
# 1                       Hubble Space Telescope satellite
# 2                       Hubble Space Telescope satellite
# 3                       Hubble Space Telescope satellite
# 4                       Hubble Space Telescope satellite
# 5                       Hubble Space Telescope satellite
# ...                                                  ...
# 5741   NASA 6.5m James Webb Space Telescope (JWST) Sa...
# 5742   NASA 6.5m James Webb Space Telescope (JWST) Sa...
# 5743   NASA 6.5m James Webb Space Telescope (JWST) Sa...
# 5744   NASA 6.5m James Webb Space Telescope (JWST) Sa...
# 5745   NASA 6.5m James Webb Space Telescope (JWST) Sa...
#
#                                          instrument
# rowid
# 1              Space Telescope Imaging Spectrograph
# 2              Space Telescope Imaging Spectrograph
# 3              Space Telescope Imaging Spectrograph
# 4              Space Telescope Imaging Spectrograph
# 5              Space Telescope Imaging Spectrograph
# ...                                             ...
# 5741   Near Infrared Spectrograph (NIRSpec) - PRISM
# 5742   Near Infrared Spectrograph (NIRSpec) - PRISM
# 5743   Near Infrared Spectrograph (NIRSpec) - PRISM
# 5744   Near Infrared Spectrograph (NIRSpec) - PRISM
# 5745   Near Infrared Spectrograph (NIRSpec) - PRISM
#
# [5745 rows x 22 columns]

# %%
EMISSION_SPECTRA_PATH = WDIR / "data/emission"
TRANSMISSION_SPECTRA_PATH = WDIR / "data/transmission"

exts = [".txt", ".csv"]

emission_files = list([p for p in Path(EMISSION_SPECTRA_PATH).rglob('*') if p.suffix in exts])
transmission_files = list([p for p in Path(TRANSMISSION_SPECTRA_PATH).rglob('*') if p.suffix in exts])

emission_file_names = ["EMISSION_" + f.name for f in emission_files]
transmission_file_names = ["TRANSMISSION_" + f.name for f in transmission_files]

print(emission_file_names)
# Out:
# ['EMISSION_WASP-121b_Emission_WFC3_Spitzer_Evans2017Nature.txt', 'EMISSION_HAT-P-32b_Emission_WFC3_Spitzer.txt', 'EMISSION_WASP-121b_Emission_WFC3_Spitzer_Evans2019.txt', 'EMISSION_HAT32A.txt', 'EMISSION_WASP76_Edwards.txt', 'EMISSION_TrES3.txt', 'EMISSION_WASP4.txt', 'EMISSION_WASP43.txt', 'EMISSION_HD209458.txt', 'EMISSION_WASP18.txt', 'EMISSION_WASP33.txt', 'EMISSION_CoRoT2.txt', 'EMISSION_WASP76_Fu.txt', 'EMISSION_HD189733.txt', 'EMISSION_WASP12.txt', 'EMISSION_WASP103.txt', 'EMISSION_KELT7.txt', 'EMISSION_WASP121.txt', 'EMISSION_Kepler13A.txt', 'EMISSION_HAT7.txt']

# %%
def compare_strings(s1, s2):
    # Remove special characters (spaces, underscores, hyphens) from both strings
    s1_clean = re.sub(r'[-_\s]', '', s1)
    s2_clean = re.sub(r'[-_\s]', '', s2)

    # Create a pattern to search for s1_clean in s2_clean
    pattern = '.*' + '.*'.join(s1_clean) + '.*'

    # Check if the pattern is found in s2_clean
    if re.fullmatch(pattern, s2_clean):
        return True
    else:
        return False

def add_file_info_to_df(df, file_list, path_list, verbose=False):
    if 'plntname' not in df.columns:
        raise ValueError('The DataFrame must contain a "plntname" column.')

    # Initialize new columns
    df['filename'] = ''
    df['path'] = ''

    # unassigned files
    unassigned = {"file": [], "path": []}

    for file, path in zip(file_list, path_list):
        assigned = False
        for index, row in df.iterrows():
            if compare_strings(row['plntname'], file):
                df.at[index, 'filename'] = file
                df.at[index, 'path'] = file  # Assuming file contains the full path. Update this line if required.
                assigned = True
        if not assigned:
            if verbose:
                print(f"No match found for {file}")
            unassigned["file"].append(file)
            unassigned["path"].append(path)

    if len(unassigned['file']) > 0:
        print(f"{len(unassigned['file'])} files of {len(file_list)} unassigned.")
    return df, unassigned

# emission_data, emission_files_unassigned = add_file_info_to_df(df_emission, emission_file_names, emission_files)
# transmission_data, transmission_files_unassigned = add_file_info_to_df(df_transmission, transmission_file_names, transmission_files)

# %%
def similarity_score(s1, s2):
    s1_clean = re.sub(r'[-_\s]', '', s1)
    s2_clean = re.sub(r'[-_\s]', '', s2)

    s1_len = len(s1_clean)
    s2_len = len(s2_clean)

    matched_chars = sum(a == b for a, b in zip(s1_clean, s2_clean))

    return matched_chars / min(s1_len, s2_len)

def add_file_info_to_df(df, file_list, path_list, verbose=False):
    if 'plntname' not in df.columns:
        raise ValueError('The DataFrame must contain a "plntname" column.')

    df['filename'] = ''
    df['path'] = ''

    unassigned_files = set(file_list)
    unassigned_rows = set(df.index)

    for file, path in zip(file_list, path_list):
        for index, row in df.iterrows():
            if row['plntname'] in file:
                df.at[index, 'filename'] = file
                df.at[index, 'path'] = file
                unassigned_files.discard(file)
                unassigned_rows.discard(index)
                break

    for file in unassigned_files:
        best_match_index = None
        best_similarity = 0
        for index in unassigned_rows:
            similarity = similarity_score(df.loc[index, 'plntname'], file)
            if similarity > best_similarity:
                best_similarity = similarity
                best_match_index = index

        if best_match_index is not None:
            df.at[best_match_index, 'filename'] = file
            df.at[best_match_index, 'path'] = file
            unassigned_rows.discard(best_match_index)

    return df

emission_data = add_file_info_to_df(df_emission, emission_file_names, emission_files)
transmission_data = add_file_info_to_df(df_transmission, transmission_file_names, transmission_files)

# %%
SPECTRA_BE_PATH = WDIR / "data/SpectraBE"
spectra_BE_files = list([p for p in Path(SPECTRA_BE_PATH).rglob('*') if p.suffix in exts])
BE_file_names = ["" + f.name.split("_")[0] for f in spectra_BE_files]

def check_overlap_with_spectraBE(file_list, be_file_list, verbose=False):
    # unassigned files
    unassigned = {"file": [], "path": []}
    matched = {"file": [], "file_BE": []}

    for file_trans in file_list:
        assigned = False
        for file_BE in be_file_list:
            if compare_strings(file_trans, file_BE):
                matched["file"].append(file_trans)
                matched["file_BE"].append(file_BE)
                assigned = True
        if not assigned:
            if verbose:
                print(f"No match found for {file_trans}")
            unassigned["file"].append(file_trans)

    if len(unassigned['file']) > 0:
        print(f"{len(unassigned['file'])} files of {len(file_list)} unassigned.")
    return matched, unassigned

def overlap_printer(overlap, unassigned):
    for i, (f1, f2) in enumerate(zip(overlap["file"], overlap["file_BE"])):
        print(f"{f1}  ->   {f2}")

    print(f"\nFiles matched:    {len(overlap['file'])} of which unique: {len(np.unique(overlap['file']))}\n")
    print(f"Files unassigned: {len(unassigned['file'])}\n")
    print(f"Unassigned files: \n")
    print(unassigned['file'])
    pass

# overlap_trans2be, unassigned_trans2be = check_overlap_with_spectraBE(transmission_file_names, BE_file_names)
overlap_be2trans, unassigned_be2trans = check_overlap_with_spectraBE(BE_file_names, transmission_file_names)

# overlap_printer(overlap_trans2be, unassigned_trans2be)
overlap_printer(overlap_be2trans, unassigned_be2trans)
# Out:
# 44 files of 70 unassigned.
# XO-1b  ->   TRANSMISSION_XO-1b_transmission_Deming2013.txt
# HAT-P-1b  ->   TRANSMISSION_HAT-P-1b_Sing_2015_Nature.csv
# HAT-P-1b  ->   TRANSMISSION_HAT-P-11b_transmission_Chachan2019.txt
# HAT-P-1b  ->   TRANSMISSION_HAT-P-12b_transmission_Sing2016.txt
# HAT-P-1b  ->   TRANSMISSION_HAT-P-1b_transmission_Sing2016.txt
# HAT-P-1b  ->   TRANSMISSION_HAT-P-12b_transmission_Wong2020.txt
# HAT-P-1b  ->   TRANSMISSION_HAT-P-11b_transmission_Fraine2014.txt
# HAT-P-1b  ->   TRANSMISSION_HAT-P-12b_Sing_2015_Nature.csv
# HAT-P-1b  ->   TRANSMISSION_HAT-P-41b_transmission-jitter_wakeford2020.txt
# HAT-P-1b  ->   TRANSMISSION_HAT-P-41b_transmission-marginalisation_wakeford2020.txt
# WASP-52b  ->   TRANSMISSION_WASP-52b_Transmission_STIS_Spitzer.txt
# WASP-17b  ->   TRANSMISSION_WASP-17b_Sing_2015_Nature.csv
# Kepler-51d  ->   TRANSMISSION_Kepler-51d_transmission_LibbyRoberts2020.txt
# HD209458b  ->   TRANSMISSION_Sing08_HD209458_STIS_lowres_bin16.txt
# HD209458b  ->   TRANSMISSION_HD209458b_transmission_Sing2016.txt
# HD209458b  ->   TRANSMISSION_HD209458b_Sing_2015_Nature.csv
# HD209458b  ->   TRANSMISSION_Sing08_HD209458_STIS_medres_bin18.txt
# HAT-P-3b  ->   TRANSMISSION_HAT-P-32b_transmission_Alam2020.txt
# HAT-P-3b  ->   TRANSMISSION_HAT-P-38b_transmission_Bruno2018.txt
# WASP-19b  ->   TRANSMISSION_WASP-19b_Sing_2015_Nature.csv
# WASP-6b  ->   TRANSMISSION_WASP-6b_transmission_Nikolov2015.txt
# WASP-6b  ->   TRANSMISSION_WASP-6b_transmission_Carter2020.txt
# WASP-6b  ->   TRANSMISSION_WASP-6b_Nikolov_2015_MNRAS.csv
# HAT-P-11b  ->   TRANSMISSION_HAT-P-11b_transmission_Chachan2019.txt
# HAT-P-11b  ->   TRANSMISSION_HAT-P-11b_transmission_Fraine2014.txt
# HAT-P-38b  ->   TRANSMISSION_HAT-P-38b_transmission_Bruno2018.txt
# HAT-P-2b  ->   TRANSMISSION_HAT-P-26b_transmission_Wakeford2017.txt
# HAT-P-2b  ->   TRANSMISSION_HAT-P-12b_transmission_Sing2016.txt
# HAT-P-2b  ->   TRANSMISSION_HAT-P-32b_transmission_Alam2020.txt
# HAT-P-2b  ->   TRANSMISSION_HAT-P-12b_transmission_Wong2020.txt
# HAT-P-2b  ->   TRANSMISSION_HAT-P-12b_Sing_2015_Nature.csv
# WASP-39b  ->   TRANSMISSION_WASP-39b_Wakeford_2018_AJ.csv
# HAT-P-12b  ->   TRANSMISSION_HAT-P-12b_transmission_Sing2016.txt
# HAT-P-12b  ->   TRANSMISSION_HAT-P-12b_transmission_Wong2020.txt
# HAT-P-12b  ->   TRANSMISSION_HAT-P-12b_Sing_2015_Nature.csv
# HD189733b  ->   TRANSMISSION_HD189733b_Sing_2015_Nature.csv
# HD189733b  ->   TRANSMISSION_HD189733b_transmission_Sing2016.txt
# HAT-P-32b  ->   TRANSMISSION_HAT-P-32b_transmission_Alam2020.txt
# GJ1214b  ->   TRANSMISSION_GJ1214b_transmission_Berta2012.txt
# GJ1214b  ->   TRANSMISSION_GJ1214b_transmission_Kreidberg2014.txt
# GJ1214b  ->   TRANSMISSION_GJ1214b_transmission_Bean2011.txt
# GJ3470b  ->   TRANSMISSION_GJ3470b_transmission_Benneke2019.txt
# HAT-P-41b  ->   TRANSMISSION_HAT-P-41b_transmission-jitter_wakeford2020.txt
# HAT-P-41b  ->   TRANSMISSION_HAT-P-41b_transmission-marginalisation_wakeford2020.txt
# GJ436b  ->   TRANSMISSION_GJ436b_transmission_Knutson2014.txt
# GJ436b  ->   TRANSMISSION_GJ436b_transmission_Lothringer2018.txt
# WASP-121b  ->   TRANSMISSION_WASP-121b_transmission_Evans2018.txt
# WASP-121b  ->   TRANSMISSION_WASP-121b_Transmission_STIS_WFC3_Evans2018_AJ.txt
# WASP-121b  ->   TRANSMISSION_WASP-121b_transmission_Evans2016.txt
# HAT-P-26b  ->   TRANSMISSION_HAT-P-26b_transmission_Wakeford2017.txt
# WASP-31b  ->   TRANSMISSION_WASP-31b_Sing_2015_MNRAS.csv
# K2-18b  ->   TRANSMISSION_K2-18b_transmission_Benneke2019.txt
# Kepler-51b  ->   TRANSMISSION_Kepler-51b_transmission_libbyRoberts2020.txt
# Kepler-51b  ->   TRANSMISSION_Kepler-51d_transmission_LibbyRoberts2020.txt
# WASP-12b  ->   TRANSMISSION_WASP-12b_transmission_Kreidberg2015.txt
# WASP-12b  ->   TRANSMISSION_WASP-12b_Sing_2013_MNRAS.csv
# WASP-12b  ->   TRANSMISSION_WASP-121b_transmission_Evans2018.txt
# WASP-12b  ->   TRANSMISSION_WASP-121b_Transmission_STIS_WFC3_Evans2018_AJ.txt
# WASP-12b  ->   TRANSMISSION_WASP-121b_transmission_Evans2016.txt
# WASP-12b  ->   TRANSMISSION_WASP-12b_transmission_Sing2016.txt
#
# Files matched:    60 of which unique: 26
#
# Files unassigned: 44
#
# Unassigned files:
#
# ['WASP-76b', 'WASP-63b', 'HD106315c', 'WASP-117b', 'WASP-62b', 'HAT-P-17b', 'WASP-107b', 'HD149026b', 'WASP-74b', 'TOI-674b', 'TOI-270d', 'WASP-29b', 'WASP-103b', 'WASP-80b', 'HAT-P-7b', 'K2-24b', 'KELT-11b', 'WASP-43b', 'WASP-18b', 'WASP-96b', 'V1298Tauc', 'HD3167c', 'HAT-P-18b', 'LTT9779b', 'TrES-2b', 'TrES-4b', 'HIP41378f', 'HD219666b', 'HIP41378b', 'WASP-101b', 'WASP-67b', 'CoRoT-1b', 'WASP-127b', 'WASP-69b', 'WASP-79b', 'Kepler-9c', 'Kepler-79d', 'KELT-1b', 'Kepler-9b', 'KELT-7b', 'WASP-178b', 'TOI-270c', 'HD97658b', 'V1298Taub']

# %%
print(transmission_file_names)
print()
print(BE_file_names)
# Out:
# ['TRANSMISSION_WASP-17b_Sing_2015_Nature.csv', 'TRANSMISSION_WASP-6b_transmission_Nikolov2015.txt', 'TRANSMISSION_WASP-12b_transmission_Kreidberg2015.txt', 'TRANSMISSION_XO-1b_transmission_Deming2013.txt', 'TRANSMISSION_TRAPPIST-1e_transmission_deWit2018.txt', 'TRANSMISSION_WASP-6b_transmission_Carter2020.txt', 'TRANSMISSION_HD189733b_Sing_2015_Nature.csv', 'TRANSMISSION_Wasp121.NUV.Sing2019.STIS.txt', 'TRANSMISSION_wasp107_G102_G141_Spake2018_Nature.txt', 'TRANSMISSION_WASP-12b_Sing_2013_MNRAS.csv', 'TRANSMISSION_HAT-P-1b_Sing_2015_Nature.csv', 'TRANSMISSION_HAT-P-26b_transmission_Wakeford2017.txt', 'TRANSMISSION_HAT-P-11b_transmission_Chachan2019.txt', 'TRANSMISSION_WASP-121b_transmission_Evans2018.txt', 'TRANSMISSION_WASP-121b_Transmission_STIS_WFC3_Evans2018_AJ.txt', 'TRANSMISSION_TRAPPIST-1g_transmission_deWit2018.txt', 'TRANSMISSION_HD97658_transmission_Knutson2014.txt', 'TRANSMISSION_HAT-P-12b_transmission_Sing2016.txt', 'TRANSMISSION_WASP-52b_Transmission_STIS_Spitzer.txt', 'TRANSMISSION_GJ3470b_transmission_Benneke2019.txt', 'TRANSMISSION_TRAPPIST-1f_transmission_deWit2018.txt', 'TRANSMISSION_Kelt11b_transmission_Colon2020.txt', 'TRANSMISSION_GJ1214b_transmission_Berta2012.txt', 'TRANSMISSION_TRAPPIST-1c_transmission_deWit2016.txt', 'TRANSMISSION_Sing08_HD209458_STIS_lowres_bin16.txt', 'TRANSMISSION_HD209458b_transmission_Sing2016.txt', 'TRANSMISSION_WASP-121b_transmission_Evans2016.txt', 'TRANSMISSION_GJ1214b_transmission_Kreidberg2014.txt', 'TRANSMISSION_HD189733b_transmission_Sing2016.txt', 'TRANSMISSION_WASP-12b_transmission_Sing2016.txt', 'TRANSMISSION_K2-18b_transmission_Benneke2019.txt', 'TRANSMISSION_WASP-6b_Nikolov_2015_MNRAS.csv', 'TRANSMISSION_TRAPPIST-1b_transmission_deWit2016.txt', 'TRANSMISSION_GJ436b_transmission_Knutson2014.txt', 'TRANSMISSION_HAT-P-1b_transmission_Sing2016.txt', 'TRANSMISSION_GJ436b_transmission_Lothringer2018.txt', 'TRANSMISSION_WASP96_FORS2.txt', 'TRANSMISSION_HAT-P-32b_transmission_Alam2020.txt', 'TRANSMISSION_GJ1214b_transmission_Bean2011.txt', 'TRANSMISSION_HAT-P-12b_transmission_Wong2020.txt', 'TRANSMISSION_HAT-P-11b_transmission_Fraine2014.txt', 'TRANSMISSION_HAT-P-38b_transmission_Bruno2018.txt', 'TRANSMISSION_HAT-P-12b_Sing_2015_Nature.csv', 'TRANSMISSION_Kepler-51b_transmission_libbyRoberts2020.txt', 'TRANSMISSION_TRAPPIST-1d_transmission_deWit2018.txt', 'TRANSMISSION_HAT-P-41b_transmission-jitter_wakeford2020.txt', 'TRANSMISSION_WASP-31b_Sing_2015_MNRAS.csv', 'TRANSMISSION_TRAPPIST-1g_transmission_Wakeford2019.txt', 'TRANSMISSION_H26_transmission_data_Wakeford2017science.txt', 'TRANSMISSION_HD209458b_Sing_2015_Nature.csv', 'TRANSMISSION_HAT-P-41b_transmission-marginalisation_wakeford2020.txt', 'TRANSMISSION_WASP-39b_Wakeford_2018_AJ.csv', 'TRANSMISSION_Sing08_HD209458_STIS_medres_bin18.txt', 'TRANSMISSION_WASP-19b_Sing_2015_Nature.csv', 'TRANSMISSION_Kepler-51d_transmission_LibbyRoberts2020.txt']
#
# ['WASP-76b', 'XO-1b', 'HAT-P-1b', 'WASP-63b', 'HD106315c', 'WASP-117b', 'WASP-52b', 'WASP-17b', 'WASP-62b', 'Kepler-51d', 'HAT-P-17b', 'HD209458b', 'WASP-107b', 'HAT-P-3b', 'WASP-19b', 'WASP-6b', 'HD149026b', 'WASP-74b', 'TOI-674b', 'TOI-270d', 'WASP-29b', 'WASP-103b', 'WASP-80b', 'HAT-P-7b', 'HAT-P-11b', 'K2-24b', 'HAT-P-38b', 'HAT-P-2b', 'KELT-11b', 'WASP-43b', 'WASP-18b', 'WASP-39b', 'WASP-96b', 'V1298Tauc', 'HAT-P-12b', 'HD189733b', 'HAT-P-32b', 'GJ1214b', 'HD3167c', 'GJ3470b', 'HAT-P-18b', 'HAT-P-41b', 'LTT9779b', 'TrES-2b', 'TrES-4b', 'HIP41378f', 'HD219666b', 'HIP41378b', 'WASP-101b', 'WASP-67b', 'CoRoT-1b', 'WASP-127b', 'WASP-69b', 'GJ436b', 'WASP-121b', 'WASP-79b', 'Kepler-9c', 'HAT-P-26b', 'WASP-31b', 'K2-18b', 'Kepler-51b', 'Kepler-79d', 'KELT-1b', 'Kepler-9b', 'KELT-7b', 'WASP-12b', 'WASP-178b', 'TOI-270c', 'HD97658b', 'V1298Taub']
