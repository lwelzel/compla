# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
res = h5py.File('/home/lukasw/Documents/git/compla/data/synthetic_spectra/WASP-39b/WASP-39b_HST_WFC3_G141_GRISM256_Wakeford+2018,TM0/WASP-39b_HST_WFC3_G141_GRISM256_Wakeford+2018,TM0_time-2023-04-26-08-55-31_output.hdf5','r') # replace this with one of your retrievals

factor=1e2

plt.figure(figsize=(10,6))
plt.errorbar(res['Observed']['wlgrid'][()], res['Observed']['spectrum'][()]*factor,
             yerr = res['Observed']['errorbars'][()]*factor,
            fmt='o', c='k', capsize=5)
# plt.xlim(0.85,1.7)
# plt.ylim(2.01,2.17)
plt.xlabel('Wavelength')
plt.ylabel('Transit Depth [%]')
plt.show()

# %%
# print(res.keys())
# print(res["ModelParameters"].keys())
# print(res["ModelParameters"].keys())
# print(res["ModelParameters"].keys())
# print(res["ModelParameters"].keys())
# print(res.walk())

def print_attrs(name, obj):
    print(name)
    # for key, val in obj.attrs.iteritems():
    #     print(key)

res.visititems(print_attrs)
# Out:
# ModelParameters
# ModelParameters/Chemistry
# ModelParameters/Chemistry/active_gases
# ModelParameters/Chemistry/chemistry_type
# ModelParameters/Chemistry/inactive_gases
# ModelParameters/Contributions
# ModelParameters/Contributions/AbsorptionContribution
# ModelParameters/Contributions/CIAContribution
# ModelParameters/Contributions/CIAContribution/cia_pairs
# ModelParameters/Contributions/HydrogenIon
# ModelParameters/Contributions/HydrogenIon/e-
# ModelParameters/Contributions/HydrogenIon/hydrogen
# ModelParameters/Contributions/RayleighContribution
# ModelParameters/Contributions/SimpleCloudsContribution
# ModelParameters/Contributions/SimpleCloudsContribution/clouds_pressure
# ModelParameters/Planet
# ModelParameters/Planet/albedo
# ModelParameters/Planet/impact_param
# ModelParameters/Planet/mass_kg
# ModelParameters/Planet/orbital_period
# ModelParameters/Planet/planet_distance
# ModelParameters/Planet/planet_mass
# ModelParameters/Planet/planet_radius
# ModelParameters/Planet/planet_type
# ModelParameters/Planet/radius_m
# ModelParameters/Planet/surface_gravity
# ModelParameters/Planet/transit_time
# ModelParameters/Pressure
# ModelParameters/Pressure/atm_max_pressure
# ModelParameters/Pressure/atm_min_pressure
# ModelParameters/Pressure/nlayers
# ModelParameters/Pressure/pressure_type
# ModelParameters/Pressure/profile
# ModelParameters/Star
# ModelParameters/Star/SED
# ModelParameters/Star/distance
# ModelParameters/Star/magnitudeK
# ModelParameters/Star/mass
# ModelParameters/Star/mass_kg
# ModelParameters/Star/metallicity
# ModelParameters/Star/radius
# ModelParameters/Star/radius_m
# ModelParameters/Star/star_type
# ModelParameters/Star/temperature
# ModelParameters/Temperature
# ModelParameters/Temperature/T
# ModelParameters/Temperature/temperature_type
# ModelParameters/model_type
# Observed
# Observed/binedges
# Observed/binwidths
# Observed/errorbars
# Observed/spectrum
# Observed/wlgrid
# Optimizer
# Optimizer/constant_efficiency
# Optimizer/derived_parameter_latex
# Optimizer/derived_parameter_names
# Optimizer/evidence_tolerance
# Optimizer/fit_boundary_high
# Optimizer/fit_boundary_low
# Optimizer/fit_parameter_latex
# Optimizer/fit_parameter_names
# Optimizer/importance_sampling
# Optimizer/max_iterations
# Optimizer/max_modes
# Optimizer/mode_tolerance
# Optimizer/nclust_parameter
# Optimizer/num_live_points
# Optimizer/optimizer
# Optimizer/sampling_eff
# Optimizer/search_multimodes
# Output
# Output/Priors
# Output/Priors/Profiles
# Output/Priors/Profiles/active_mix_profile
# Output/Priors/Profiles/altitude_profile
# Output/Priors/Profiles/density_profile
# Output/Priors/Profiles/gravity_profile
# Output/Priors/Profiles/inactive_mix_profile
# Output/Priors/Profiles/mu_profile
# Output/Priors/Profiles/pressure_profile
# Output/Priors/Profiles/scaleheight_profile
# Output/Priors/Profiles/temp_profile
# Output/Priors/Spectra
# Output/Priors/Spectra/Contributions
# Output/Priors/Spectra/Contributions/Absorption
# Output/Priors/Spectra/Contributions/Absorption/CH4
# Output/Priors/Spectra/Contributions/Absorption/CH4/binned_spectrum
# Output/Priors/Spectra/Contributions/Absorption/CH4/native_spectrum
# Output/Priors/Spectra/Contributions/Absorption/CO
# Output/Priors/Spectra/Contributions/Absorption/CO/binned_spectrum
# Output/Priors/Spectra/Contributions/Absorption/CO/native_spectrum
# Output/Priors/Spectra/Contributions/Absorption/CO2
# Output/Priors/Spectra/Contributions/Absorption/CO2/binned_spectrum
# Output/Priors/Spectra/Contributions/Absorption/CO2/native_spectrum
# Output/Priors/Spectra/Contributions/Absorption/H2O
# Output/Priors/Spectra/Contributions/Absorption/H2O/binned_spectrum
# Output/Priors/Spectra/Contributions/Absorption/H2O/native_spectrum
# Output/Priors/Spectra/Contributions/Absorption/NH3
# Output/Priors/Spectra/Contributions/Absorption/NH3/binned_spectrum
# Output/Priors/Spectra/Contributions/Absorption/NH3/native_spectrum
# Output/Priors/Spectra/Contributions/Absorption/TiO
# Output/Priors/Spectra/Contributions/Absorption/TiO/binned_spectrum
# Output/Priors/Spectra/Contributions/Absorption/TiO/native_spectrum
# Output/Priors/Spectra/Contributions/Absorption/VO
# Output/Priors/Spectra/Contributions/Absorption/VO/binned_spectrum
# Output/Priors/Spectra/Contributions/Absorption/VO/native_spectrum
# Output/Priors/Spectra/Contributions/Absorption/binned_spectrum
# Output/Priors/Spectra/Contributions/Absorption/native_spectrum
# Output/Priors/Spectra/Contributions/CIA
# Output/Priors/Spectra/Contributions/CIA/H2-H2
# Output/Priors/Spectra/Contributions/CIA/H2-H2/binned_spectrum
# Output/Priors/Spectra/Contributions/CIA/H2-H2/native_spectrum
# Output/Priors/Spectra/Contributions/CIA/H2-He
# Output/Priors/Spectra/Contributions/CIA/H2-He/binned_spectrum
# Output/Priors/Spectra/Contributions/CIA/H2-He/native_spectrum
# Output/Priors/Spectra/Contributions/CIA/binned_spectrum
# Output/Priors/Spectra/Contributions/CIA/native_spectrum
# Output/Priors/Spectra/Contributions/HydrogenIon
# Output/Priors/Spectra/Contributions/HydrogenIon/HydrogenIon
# Output/Priors/Spectra/Contributions/HydrogenIon/HydrogenIon/binned_spectrum
# Output/Priors/Spectra/Contributions/HydrogenIon/HydrogenIon/native_spectrum
# Output/Priors/Spectra/Contributions/HydrogenIon/binned_spectrum
# Output/Priors/Spectra/Contributions/HydrogenIon/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh
# Output/Priors/Spectra/Contributions/Rayleigh/CH4
# Output/Priors/Spectra/Contributions/Rayleigh/CH4/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/CH4/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/CO
# Output/Priors/Spectra/Contributions/Rayleigh/CO/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/CO/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/CO2
# Output/Priors/Spectra/Contributions/Rayleigh/CO2/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/CO2/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/H2
# Output/Priors/Spectra/Contributions/Rayleigh/H2/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/H2/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/H2O
# Output/Priors/Spectra/Contributions/Rayleigh/H2O/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/H2O/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/He
# Output/Priors/Spectra/Contributions/Rayleigh/He/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/He/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/N2
# Output/Priors/Spectra/Contributions/Rayleigh/N2/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/N2/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/NH3
# Output/Priors/Spectra/Contributions/Rayleigh/NH3/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/NH3/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/O2
# Output/Priors/Spectra/Contributions/Rayleigh/O2/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/O2/native_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/binned_spectrum
# Output/Priors/Spectra/Contributions/Rayleigh/native_spectrum
# Output/Priors/Spectra/Contributions/SimpleClouds
# Output/Priors/Spectra/Contributions/SimpleClouds/Clouds
# Output/Priors/Spectra/Contributions/SimpleClouds/Clouds/binned_spectrum
# Output/Priors/Spectra/Contributions/SimpleClouds/Clouds/native_spectrum
# Output/Priors/Spectra/Contributions/SimpleClouds/binned_spectrum
# Output/Priors/Spectra/Contributions/SimpleClouds/native_spectrum
# Output/Priors/Spectra/binned_spectrum
# Output/Priors/Spectra/binned_tau
# Output/Priors/Spectra/binned_wlgrid
# Output/Priors/Spectra/binned_wlwidth
# Output/Priors/Spectra/binned_wngrid
# Output/Priors/Spectra/binned_wnwidth
# Output/Priors/Spectra/instrument_noise
# Output/Priors/Spectra/instrument_spectrum
# Output/Priors/Spectra/instrument_wlgrid
# Output/Priors/Spectra/instrument_wngrid
# Output/Priors/Spectra/instrument_wnwidth
# Output/Priors/Spectra/native_spectrum
# Output/Priors/Spectra/native_wlgrid
# Output/Priors/Spectra/native_wlwidth
# Output/Priors/Spectra/native_wngrid
# Output/Priors/Spectra/native_wnwidth
# Output/Solutions
# Output/Solutions/GlobalStats
# Output/Solutions/GlobalStats/global evidence
# Output/Solutions/GlobalStats/global evidence error
# Output/Solutions/GlobalStats/marginals0
# Output/Solutions/GlobalStats/marginals0/1sigma
# Output/Solutions/GlobalStats/marginals0/2sigma
# Output/Solutions/GlobalStats/marginals0/3sigma
# Output/Solutions/GlobalStats/marginals0/5sigma
# Output/Solutions/GlobalStats/marginals0/median
# Output/Solutions/GlobalStats/marginals0/q01%
# Output/Solutions/GlobalStats/marginals0/q10%
# Output/Solutions/GlobalStats/marginals0/q25%
# Output/Solutions/GlobalStats/marginals0/q75%
# Output/Solutions/GlobalStats/marginals0/q90%
# Output/Solutions/GlobalStats/marginals0/q99%
# Output/Solutions/GlobalStats/marginals0/sigma
# Output/Solutions/GlobalStats/marginals1
# Output/Solutions/GlobalStats/marginals1/1sigma
# Output/Solutions/GlobalStats/marginals1/2sigma
# Output/Solutions/GlobalStats/marginals1/3sigma
# Output/Solutions/GlobalStats/marginals1/5sigma
# Output/Solutions/GlobalStats/marginals1/median
# Output/Solutions/GlobalStats/marginals1/q01%
# Output/Solutions/GlobalStats/marginals1/q10%
# Output/Solutions/GlobalStats/marginals1/q25%
# Output/Solutions/GlobalStats/marginals1/q75%
# Output/Solutions/GlobalStats/marginals1/q90%
# Output/Solutions/GlobalStats/marginals1/q99%
# Output/Solutions/GlobalStats/marginals1/sigma
# Output/Solutions/GlobalStats/marginals2
# Output/Solutions/GlobalStats/marginals2/1sigma
# Output/Solutions/GlobalStats/marginals2/2sigma
# Output/Solutions/GlobalStats/marginals2/3sigma
# Output/Solutions/GlobalStats/marginals2/5sigma
# Output/Solutions/GlobalStats/marginals2/median
# Output/Solutions/GlobalStats/marginals2/q01%
# Output/Solutions/GlobalStats/marginals2/q10%
# Output/Solutions/GlobalStats/marginals2/q25%
# Output/Solutions/GlobalStats/marginals2/q75%
# Output/Solutions/GlobalStats/marginals2/q90%
# Output/Solutions/GlobalStats/marginals2/q99%
# Output/Solutions/GlobalStats/marginals2/sigma
# Output/Solutions/GlobalStats/marginals3
# Output/Solutions/GlobalStats/marginals3/1sigma
# Output/Solutions/GlobalStats/marginals3/2sigma
# Output/Solutions/GlobalStats/marginals3/3sigma
# Output/Solutions/GlobalStats/marginals3/5sigma
# Output/Solutions/GlobalStats/marginals3/median
# Output/Solutions/GlobalStats/marginals3/q01%
# Output/Solutions/GlobalStats/marginals3/q10%
# Output/Solutions/GlobalStats/marginals3/q25%
# Output/Solutions/GlobalStats/marginals3/q75%
# Output/Solutions/GlobalStats/marginals3/q90%
# Output/Solutions/GlobalStats/marginals3/q99%
# Output/Solutions/GlobalStats/marginals3/sigma
# Output/Solutions/GlobalStats/marginals4
# Output/Solutions/GlobalStats/marginals4/1sigma
# Output/Solutions/GlobalStats/marginals4/2sigma
# Output/Solutions/GlobalStats/marginals4/3sigma
# Output/Solutions/GlobalStats/marginals4/5sigma
# Output/Solutions/GlobalStats/marginals4/median
# Output/Solutions/GlobalStats/marginals4/q01%
# Output/Solutions/GlobalStats/marginals4/q10%
# Output/Solutions/GlobalStats/marginals4/q25%
# Output/Solutions/GlobalStats/marginals4/q75%
# Output/Solutions/GlobalStats/marginals4/q90%
# Output/Solutions/GlobalStats/marginals4/q99%
# Output/Solutions/GlobalStats/marginals4/sigma
# Output/Solutions/GlobalStats/modes0
# Output/Solutions/GlobalStats/modes0/index
# Output/Solutions/GlobalStats/modes0/local log-evidence
# Output/Solutions/GlobalStats/modes0/local log-evidence error
# Output/Solutions/GlobalStats/modes0/maximum
# Output/Solutions/GlobalStats/modes0/maximum a posterior
# Output/Solutions/GlobalStats/modes0/mean
# Output/Solutions/GlobalStats/modes0/sigma
# Output/Solutions/GlobalStats/modes0/strictly local log-evidence
# Output/Solutions/GlobalStats/modes0/strictly local log-evidence error
# Output/Solutions/GlobalStats/nested sampling global log-evidence
# Output/Solutions/GlobalStats/nested sampling global log-evidence error
# Output/Solutions/solution0
# Output/Solutions/solution0/Profiles
# Output/Solutions/solution0/Profiles/active_mix_profile
# Output/Solutions/solution0/Profiles/active_mix_profile_std
# Output/Solutions/solution0/Profiles/altitude_profile
# Output/Solutions/solution0/Profiles/density_profile
# Output/Solutions/solution0/Profiles/gravity_profile
# Output/Solutions/solution0/Profiles/inactive_mix_profile
# Output/Solutions/solution0/Profiles/inactive_mix_profile_std
# Output/Solutions/solution0/Profiles/mu_profile
# Output/Solutions/solution0/Profiles/pressure_profile
# Output/Solutions/solution0/Profiles/scaleheight_profile
# Output/Solutions/solution0/Profiles/temp_profile
# Output/Solutions/solution0/Profiles/temp_profile_std
# Output/Solutions/solution0/Spectra
# Output/Solutions/solution0/Spectra/Contributions
# Output/Solutions/solution0/Spectra/Contributions/Absorption
# Output/Solutions/solution0/Spectra/Contributions/Absorption/CH4
# Output/Solutions/solution0/Spectra/Contributions/Absorption/CH4/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/CH4/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/CO
# Output/Solutions/solution0/Spectra/Contributions/Absorption/CO/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/CO/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/CO2
# Output/Solutions/solution0/Spectra/Contributions/Absorption/CO2/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/CO2/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/H2O
# Output/Solutions/solution0/Spectra/Contributions/Absorption/H2O/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/H2O/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/NH3
# Output/Solutions/solution0/Spectra/Contributions/Absorption/NH3/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/NH3/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/TiO
# Output/Solutions/solution0/Spectra/Contributions/Absorption/TiO/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/TiO/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/VO
# Output/Solutions/solution0/Spectra/Contributions/Absorption/VO/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/VO/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Absorption/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/CIA
# Output/Solutions/solution0/Spectra/Contributions/CIA/H2-H2
# Output/Solutions/solution0/Spectra/Contributions/CIA/H2-H2/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/CIA/H2-H2/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/CIA/H2-He
# Output/Solutions/solution0/Spectra/Contributions/CIA/H2-He/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/CIA/H2-He/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/CIA/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/CIA/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/HydrogenIon
# Output/Solutions/solution0/Spectra/Contributions/HydrogenIon/HydrogenIon
# Output/Solutions/solution0/Spectra/Contributions/HydrogenIon/HydrogenIon/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/HydrogenIon/HydrogenIon/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/HydrogenIon/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/HydrogenIon/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/CH4
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/CH4/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/CH4/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/CO
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/CO/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/CO/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/CO2
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/CO2/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/CO2/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/H2
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/H2/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/H2/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/H2O
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/H2O/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/H2O/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/He
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/He/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/He/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/N2
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/N2/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/N2/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/NH3
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/NH3/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/NH3/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/O2
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/O2/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/O2/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/Rayleigh/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/SimpleClouds
# Output/Solutions/solution0/Spectra/Contributions/SimpleClouds/Clouds
# Output/Solutions/solution0/Spectra/Contributions/SimpleClouds/Clouds/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/SimpleClouds/Clouds/native_spectrum
# Output/Solutions/solution0/Spectra/Contributions/SimpleClouds/binned_spectrum
# Output/Solutions/solution0/Spectra/Contributions/SimpleClouds/native_spectrum
# Output/Solutions/solution0/Spectra/binned_spectrum
# Output/Solutions/solution0/Spectra/binned_std
# Output/Solutions/solution0/Spectra/binned_tau
# Output/Solutions/solution0/Spectra/binned_wlgrid
# Output/Solutions/solution0/Spectra/binned_wlwidth
# Output/Solutions/solution0/Spectra/binned_wngrid
# Output/Solutions/solution0/Spectra/binned_wnwidth
# Output/Solutions/solution0/Spectra/native_spectrum
# Output/Solutions/solution0/Spectra/native_std
# Output/Solutions/solution0/Spectra/native_wlgrid
# Output/Solutions/solution0/Spectra/native_wlwidth
# Output/Solutions/solution0/Spectra/native_wngrid
# Output/Solutions/solution0/Spectra/native_wnwidth
# Output/Solutions/solution0/Statistics
# Output/Solutions/solution0/Statistics/local log-evidence
# Output/Solutions/solution0/Statistics/local log-evidence error
# Output/Solutions/solution0/derived_params
# Output/Solutions/solution0/derived_params/mu_derived
# Output/Solutions/solution0/derived_params/mu_derived/mean
# Output/Solutions/solution0/derived_params/mu_derived/sigma_m
# Output/Solutions/solution0/derived_params/mu_derived/sigma_p
# Output/Solutions/solution0/derived_params/mu_derived/trace
# Output/Solutions/solution0/derived_params/mu_derived/value
# Output/Solutions/solution0/fit_params
# Output/Solutions/solution0/fit_params/Offset_2
# Output/Solutions/solution0/fit_params/Offset_2/mean
# Output/Solutions/solution0/fit_params/Offset_2/nest_map
# Output/Solutions/solution0/fit_params/Offset_2/nest_sigma
# Output/Solutions/solution0/fit_params/Offset_2/sigma_m
# Output/Solutions/solution0/fit_params/Offset_2/sigma_p
# Output/Solutions/solution0/fit_params/Offset_2/trace
# Output/Solutions/solution0/fit_params/Offset_2/value
# Output/Solutions/solution0/fit_params/T
# Output/Solutions/solution0/fit_params/T/mean
# Output/Solutions/solution0/fit_params/T/nest_map
# Output/Solutions/solution0/fit_params/T/nest_sigma
# Output/Solutions/solution0/fit_params/T/sigma_m
# Output/Solutions/solution0/fit_params/T/sigma_p
# Output/Solutions/solution0/fit_params/T/trace
# Output/Solutions/solution0/fit_params/T/value
# Output/Solutions/solution0/fit_params/log_C_O_ratio
# Output/Solutions/solution0/fit_params/log_C_O_ratio/mean
# Output/Solutions/solution0/fit_params/log_C_O_ratio/nest_map
# Output/Solutions/solution0/fit_params/log_C_O_ratio/nest_sigma
# Output/Solutions/solution0/fit_params/log_C_O_ratio/sigma_m
# Output/Solutions/solution0/fit_params/log_C_O_ratio/sigma_p
# Output/Solutions/solution0/fit_params/log_C_O_ratio/trace
# Output/Solutions/solution0/fit_params/log_C_O_ratio/value
# Output/Solutions/solution0/fit_params/metallicity
# Output/Solutions/solution0/fit_params/metallicity/mean
# Output/Solutions/solution0/fit_params/metallicity/nest_map
# Output/Solutions/solution0/fit_params/metallicity/nest_sigma
# Output/Solutions/solution0/fit_params/metallicity/sigma_m
# Output/Solutions/solution0/fit_params/metallicity/sigma_p
# Output/Solutions/solution0/fit_params/metallicity/trace
# Output/Solutions/solution0/fit_params/metallicity/value
# Output/Solutions/solution0/fit_params/planet_radius
# Output/Solutions/solution0/fit_params/planet_radius/mean
# Output/Solutions/solution0/fit_params/planet_radius/nest_map
# Output/Solutions/solution0/fit_params/planet_radius/nest_sigma
# Output/Solutions/solution0/fit_params/planet_radius/sigma_m
# Output/Solutions/solution0/fit_params/planet_radius/sigma_p
# Output/Solutions/solution0/fit_params/planet_radius/trace
# Output/Solutions/solution0/fit_params/planet_radius/value
# Output/Solutions/solution0/tracedata
# Output/Solutions/solution0/weights

# %%
from pathlib import Path

WDIR = Path().cwd().parent

path_list = [
    str(WDIR / "data/taurex_lightcurves_LW" / "HAT-P-1-b_HST_STIS_G430L_52X2_Nikolov+2014.txt"),
    str(WDIR / "data/taurex_lightcurves_LW" / "HAT-P-1-b_HST_STIS_G430L_52X2_Sing+2016.txt"),
    str(WDIR / "data/synthetic_spectra/HAT-P-1b" / "synthetic_HAT-P-1-b_HST_STIS_G430L_52X2_Nikolov+2014_transmission_spectrum_0.txt"),
    str(WDIR / "data/synthetic_spectra/HAT-P-1b" / "synthetic_HAT-P-1-b_HST_STIS_G430L_52X2_Sing+2016_transmission_spectrum_1.txt"),
]

# syn_spectrum = np.loadtxt(str(WDIR / f"data/synthetic_spectra/HAT-P-1b/synthetic_HAT-P-1b_transmission_spectrum_1.txt")).T
# real_spectrum1 = np.loadtxt(str(WDIR / "data/taurex_lightcurves_LW/HAT-P-1-b_HST_STIS_G430L_52X2_Sing+2016.txt")).T
# real_spectrum2 = np.loadtxt(str(WDIR / "data/SpectraBE/HAT-P-1b_G141.txt")).T

factor=1e2

plt.figure(figsize=(10,6))

for spectrum, c in zip(path_list, ["r", "g", "cyan", "lightblue"]):
    spectrum = np.loadtxt(spectrum).T
    plt.errorbar(spectrum[0], spectrum[1]*factor,
                 yerr = spectrum[2]*factor,
                fmt='D', c=c, capsize=5)

# plt.xlim(0.85,1.7)
# plt.ylim(2.01,2.17)
plt.xlabel('Wavelength')
plt.ylabel('Transit Depth [%]')
plt.show()

# %%
res_spec = res['Output']['Solutions']['solution0']['Spectra']

"""You can plot the best-fit spectrum at the binned resolution but it looks ugly"""

plt.figure(figsize=(10,6))
plt.errorbar(res['Observed']['wlgrid'][()], res['Observed']['spectrum'][()]*factor, 
             yerr = res['Observed']['errorbars'][()]*factor,
            fmt='o', c='k', capsize=5)
plt.plot(res_spec['binned_wlgrid'][()],res_spec['binned_spectrum'][()]*factor,c='r')
# plt.xlim(0.85, 1.7)
# plt.ylim(2.01, 2.17)
plt.xlabel('Wavelength')
plt.ylabel('Transit Depth [%]')
plt.show()

# %%
"""Same for the native...."""

plt.figure(figsize=(10,6))
plt.errorbar(res['Observed']['wlgrid'][()], res['Observed']['spectrum'][()]*factor, 
             yerr = res['Observed']['errorbars'][()]*factor,
            fmt='o', c='k', capsize=5)
plt.plot(res_spec['native_wlgrid'][()],res_spec['native_spectrum'][()]*factor,c='r')
# plt.xlim(0.85,1.7)
# plt.ylim(2.01,2.17)
plt.xlabel('Wavelength')
plt.ylabel('Transit Depth [%]')
plt.show()

# %%
from taurex.binning.fluxbinner import FluxBinner
from taurex.util.util import wnwidth_to_wlwidth
import pandas as pd

def bin_spectrum(low_res, high_res):
        
    transmission_spectra = high_res.sort_values(by = 'wavelength')
    low_res = low_res.sort_values(by = 'wavelength')
    low_res = low_res.reset_index(drop = True)
    
    binner  = FluxBinner(low_res['wavelength'].values)

    _, binned_transit_depth, _,  _ = binner.bindown(transmission_spectra['wavelength'].values, 
                                                    transmission_spectra['depth'].values)
    
    return np.array(binned_transit_depth)

"""So let's bin it tro something in-between"""

hr = pd.DataFrame(res_spec['native_wlgrid'][()],columns=['wavelength'])
hr['depth'] = res_spec['native_spectrum'][()]

bd = 0.005
lr = pd.DataFrame(np.arange(0.6,5,bd),columns=['wavelength'])
lr['depth'] = bin_spectrum(lr.copy(), hr)

plt.figure(figsize=(10,6))
plt.errorbar(res['Observed']['wlgrid'][()], res['Observed']['spectrum'][()]*factor, 
             yerr = res['Observed']['errorbars'][()]*factor,
            fmt='o', c='k', capsize=5)
plt.plot(lr['wavelength'],lr['depth']*factor,c='r')
# plt.xlim(0.85,1.7)
# plt.ylim(2.01,2.17)
plt.xlabel('Wavelength')
plt.ylabel('Transit Depth [%]')
plt.show()
# Out:
# Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).

# %%
"""Might also want to plot 1 sigma uncertainities on the best-fit model..."""

hr_plus_std = hr.copy()
hr_plus_std['depth'] = res_spec['native_spectrum'][()] + res_spec['native_std'][()]

hr_minus_std = hr.copy()
hr_minus_std['depth'] = res_spec['native_spectrum'][()] - res_spec['native_std'][()]

lr['depth_m_std'] = bin_spectrum(lr.copy(), hr_minus_std)
lr['depth_p_std'] = bin_spectrum(lr.copy(), hr_plus_std)

plt.figure(figsize=(10,6))
plt.errorbar(res['Observed']['wlgrid'][()], res['Observed']['spectrum'][()]*factor, 
             yerr = res['Observed']['errorbars'][()]*factor,
            fmt='o', c='k', capsize=5)
plt.plot(lr['wavelength'],lr['depth']*factor,c='r')
plt.fill_between(lr['wavelength'],lr['depth_m_std']*factor,lr['depth_p_std']*factor,color='r',alpha=0.3)
# plt.xlim(0.85,1.7)
# plt.ylim(2.01,2.17)
plt.xlabel('Wavelength')
plt.ylabel('Transit Depth [%]')
plt.show()

# %%
"""Can also be interesting to project to longer wavelengths. In this case, the big uncertainty at ~4.5
micron is because the retrieval could not well constrain carbon-bearing species (e.g., CO2)"""

plt.figure(figsize=(10,6))
plt.errorbar(res['Observed']['wlgrid'][()], res['Observed']['spectrum'][()]*factor, 
             yerr = res['Observed']['errorbars'][()]*factor,
            fmt='o', c='k', capsize=5)
plt.plot(lr['wavelength'],lr['depth']*factor,c='r')
plt.fill_between(lr['wavelength'],lr['depth_m_std']*factor,lr['depth_p_std']*factor,color='r',alpha=0.3)
# plt.xlim(0.85,5.)
# plt.ylim(2.01,2.17)
plt.xlabel('Wavelength')
plt.ylabel('Transit Depth [%]')
plt.show()

# %%
#Get the Bayesian evidence, ln(E)
evidence = res['Output']['Solutions']['solution0']['Statistics']['local log-evidence'][()]
evidence
# Out:
# 297.9760824728133

# %%
import scipy as sp
from scipy.special import *
from numpy import interp

"""A function to compare the Bayesian evidence and convert the difference to sigma"""

def sigma(lnz1,lnz2):
    
    lnB = lnz1 - lnz2
    logp = np.arange(-100.00,0.00,.1) #reverse order
    logp = logp[::-1] # original order
    P = 10.0**logp
    Barr = -1./(np.exp(1)*P*np.log(P))

    sigma = np.arange(0.1,100.10,.01)
    p_p = sp.special.erfc(sigma/np.sqrt(2.0))
    B = np.exp(lnB)
    pvalue = 10.0**interp(np.log10(B),np.log10(Barr),np.log10(P))
    sig = interp(pvalue,p_p[::-1],sigma[::-1])
                
    return sig

evidence_2 = 252

sigma(evidence,evidence_2)
# Out:
# 9.83717724576677

# %%
"""output file also contrains all the traces so you can replot the posteriors"""

fit_para = res['Optimizer']['fit_parameter_names'][()]
final_para = res['Output']['Solutions']['solution0']['fit_params']

print(fit_para) # list of fitted parameters

traces = res['Output']['Solutions']['solution0']['tracedata'][()]

#lets plot the offset between G102 and G141
idx=11
plt.figure()
plt.hist(traces[:,idx]*1e6, bins=np.arange(-500,500,10),color='r',alpha=0.3)
plt.errorbar(final_para['Offset_1']['value'][()]*1e6, 500, 
             xerr=[[final_para['Offset_1']['sigma_m'][()]*1e6],[final_para['Offset_1']['sigma_p'][()]*1e6]],
            fmt='o',c='k')
plt.title(fit_para[idx])
plt.yticks([])
plt.show()
# Out:
# [[b'planet_radius']
#  [b'T']
#  [b'ace_metallicity']
#  [b'C_O_ratio']]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 13
#      11 idx=11
#      12 plt.figure()
# ---> 13 plt.hist(traces[:,idx]*1e6, bins=np.arange(-500,500,10),color='r',alpha=0.3)
#      14 plt.errorbar(final_para['Offset_1']['value'][()]*1e6, 500,
#      15              xerr=[[final_para['Offset_1']['sigma_m'][()]*1e6],[final_para['Offset_1']['sigma_p'][()]*1e6]],
#      16             fmt='o',c='k')
#      17 plt.title(fit_para[idx])
#
# IndexError: index 11 is out of bounds for axis 1 with size 4
